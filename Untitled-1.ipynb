# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# %pip install nltk

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

plt.style.use("ggplot")

# %%
# Read the file and store as dataframe 
df = pd.read_csv("AmazonReview/Reviews.csv")
df.head(10) # printing 1st 10 dataframe data
# Out:
#    Unnamed: 0  Id   ProductId          UserId
# 0           0   1  B001E4KFG0  A3SGXH7AUHU8GW  \
# 1           1   2  B00813GRG4  A1D87F6ZCVE5NK
# 2           2   3  B000LQOCH0   ABXLMWJIXXAIN
# 3           3   4  B000UA0QIQ  A395BORC6FGVXV
# 4           4   5  B006K2ZZ7K  A1UQRSCLF8GW1T
# 5           5   6  B006K2ZZ7K   ADT0SRK1MGOEU
# 6           6   7  B006K2ZZ7K  A1SP2KVKFXXRU1
# 7           7   8  B006K2ZZ7K  A3JRGQVEQN31IQ
# 8           8   9  B000E7L2R4  A1MZYO9TZK0BBI
# 9           9  10  B00171APVA  A21BT40VZCCYT4
#
#                        ProfileName  HelpfulnessNumerator
# 0                       delmartian                     1  \
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
# 5                   Twoapennything                     0
# ...

# %%
# # Number of time each score occurs 
# df["Score"].value_counts()

# # Number of time each score occured are sorted in assending order
# df["Score"].value_counts().sort_index()

# %% [markdown]
# # Quick EDA

# %%
# Numeber of time each score occurs 
axis = df["Score"].value_counts().sort_index()\
    .plot(kind = "bar", title="Count of Review by Stars",
        figsize=(10,5))
axis.set_xlabel("Review Stars")
plt.show()

# %% [markdown]
# # Basic NLTK

# %%
# Extracting one sample text from dataframe 
text = df["Text"][1]
text
# Out:
# 'Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".'

# %%
# Tokenize the text into individual words/tokens
# nltk.download('punkt')
tokens = nltk.word_tokenize(text)
tokens[:10]
# Out:
# ['Product',
#  'arrived',
#  'labeled',
#  'as',
#  'Jumbo',
#  'Salted',
#  'Peanuts',
#  '...',
#  'the',
#  'peanuts']

# %%
# Perform Part-Of-Speech tagging on the tokens
# nltk.download('averaged_perceptron_tagger')
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('Product', 'NNP'),
#  ('arrived', 'VBD'),
#  ('labeled', 'VBN'),
#  ('as', 'IN'),
#  ('Jumbo', 'NNP'),
#  ('Salted', 'NNP'),
#  ('Peanuts', 'NNP'),
#  ('...', ':'),
#  ('the', 'DT'),
#  ('peanuts', 'NNS')]

# %%
# Perform named entity recognition
# nltk.download('maxent_ne_chunker')
entities = nltk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   (GPE Product/NNP)
#   arrived/VBD
#   labeled/VBN
#   as/IN
#   (PERSON Jumbo/NNP Salted/NNP Peanuts/NNP)
#   .../:
#   the/DT
#   peanuts/NNS
#   were/VBD
#   actually/RB
#   small/JJ
#   sized/VBN
#   unsalted/JJ
#   ./.
#   Not/RB
#   sure/JJ
#   if/IN
#   this/DT
#   was/VBD
#   an/DT
#   error/NN
#   or/CC
#   if/IN
#   the/DT
#   vendor/NN
#   intended/VBN
#   to/TO
#   represent/VB
#   the/DT
#   product/NN
#   as/IN
#   ``/``
#   Jumbo/NNP
#   ''/''
#   ./.)

# %%
data = pd.read_csv('AmazonReview\preprocessed_reviews.csv')
# Out:
#                                                   Text  Score Sentiment
# 45   This seems a little more wholesome than some o...      3   neutral
# 47   The flavors are good.  However, I do not see a...      3   neutral
# 49   This is the same stuff you can buy at the big ...      3   neutral
# 53   we're used to spicy foods down here in south t...      3   neutral
# 60   Watch your prices with this.  While the assort...      3   neutral
# ..                                                 ...    ...       ...
# 915  My baby LOVES sweet potatoes. I can essentiall...      3   neutral
# 922  I introduced my daughter to Earth's Best Organ...      3   neutral
# 923  We received this in a dinner variety pack and ...      3   neutral
# 932  Little Baby Picky will only eat this sometimes...      3   neutral
# 965  I purchased this for a friend who loves to coo...      3   neutral
#
# [75 rows x 3 columns]
